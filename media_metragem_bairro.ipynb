# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
data = pd.read_csv(url)
data.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
data.sample(10)
# Out:
#                                           Rua               Bairro     Cidade  \
# 713           Rua Professor Filadelfo Azevedo  Vila Nova Conceição  São Paulo
# 482                     Rua Paulo Rafael, 51             Vila Hebe  São Paulo
# 98                    Rua Marechal Bitencourt      Jardim Paulista  São Paulo
# 9986                            Rua Luisiania    Brooklin Paulista  São Paulo
# 8882                              Rua Camundo    Planalto Paulista  São Paulo
# 5519                              Rua Martins              Butantã  São Paulo
# 8157                        Rua dos Militares       Vila Albertina  São Paulo
# 426                               Rua Geórgia    Brooklin Paulista  São Paulo
# 4025                      Rua Teixeira Mendes            Liberdade  São Paulo
# 4097  Avenida Professor Fonseca Rodrigues, 0     Alto de Pinheiros  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas         Valor
# ...

# %%
data.Metragem.mean()
# Out:
# 442.30065947242207

# %%
data.Bairro.value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = data.Bairro.value_counts()

# %%
media_metragem = data.Metragem.mean()

# %%
media_metragemBairro = n_imoveis_bairro + media_metragem

# %%
print(media_metragemBairro)
# Out:
# Alto de Pinheiros     851.300659
# Jardim Guedala        845.300659
# Jardim Paulista       751.300659
# Brooklin Paulista     689.300659
# Jardim Europa         682.300659
#                          ...
# Jardim das Imbuias    443.300659
# Vila Represa          443.300659
# Vila Nancy            443.300659
# Sítio Represa         443.300659
# Vila Invernada        443.300659
# Name: Bairro, Length: 701, dtype: float64
